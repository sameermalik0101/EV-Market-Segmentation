# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel(r"C:\Users\Saad\Desktop\Data.xlsx")

# %%
df.head()
# Out:
#    S.No                    Company  \
# 0     1  Maruti Suzuki India Ltd.,
# 1     2  Maruti Suzuki India Ltd.,
# 2     3  Maruti Suzuki India Ltd.,
# 3     4      Tvs Motor Company Ltd
# 4     5      Tvs Motor Company Ltd
#
#                                                Model             Fuel  \
# 0  MARUTI - CIAZ SMART HYBRID SIGMA 1.5L 5MT BSVI...  Petrol Electric
# 1  MARUTI - CIAZ SMART HYBRID SIGMA 1.5L 5MT BSVI...  Petrol Electric
# 2  MARUTI - CIAZ SMART HYBRID SIGMA 1.5L 5MT BSVI...  Petrol Electric
# 3                           TVS IQUBE ELECTRIC S BOV          Battery
# 4                TVS IQUBE ELECTRIC SMARTXONNECT BOV          Battery
#
#   Vehicle Class  Insurance Validity (in years)  Vehicle age (in months)  \
# 0     Motor Cab                              3                        6
# 1     Motor Cab                              3                        6
# 2     Motor Cab                              3                        6
# ...

# %%
df.shape
# Out:
# (8691, 14)

# %%
df.select_dtypes(include=np.number)
df.select_dtypes(include=np.number).columns.tolist()
# Out:
# ['S.No',
#  'Insurance Validity (in years)',
#  'Vehicle age (in months)',
#  'Seats',
#  'CC',
#  'Cylinders',
#  'HP']

# %%
string=['object']
df.select_dtypes(include=string)
df.select_dtypes(include=string).columns.tolist()
# Out:
# ['Company',
#  'Model',
#  'Fuel',
#  'Vehicle Class',
#  'Second Vehicle',
#  'Category',
#  'Body Type']

# %%
df.isnull().sum()
# Out:
# S.No                             0
# Company                          0
# Model                            0
# Fuel                             0
# Vehicle Class                    0
# Insurance Validity (in years)    0
# Vehicle age (in months)          0
# Seats                            0
# Second Vehicle                   0
# Category                         0
# Body Type                        0
# CC                               0
# Cylinders                        0
# HP                               0
# dtype: int64

# %%
f, ax = plt.subplots(figsize=(12, 8))
sns.countplot(x = 'Company' , data =df)
ax.tick_params(axis='x', rotation=90)

# %%
counts = df['Model'].value_counts()

# %%
a = counts.sort_values(ascending= False)

# %%
a[0:10]
# Out:
# TVS IQUBE ELECTRIC S BOV               1501
# OLA S1 AIR BOV                         1113
# CHETAK 2413 PREMIUM BOV                1103
# TVS IQUBE ELECTRIC SMARTXONNECT BOV     936
# OLA S1 PRO (GEN2) BOV                   690
# VIDA V1 PRO BOV                         479
# TVS IQUBE ELECTRIC BOV                  245
# BZINESS PRO BOV                         200
# MAGNUS EX BOV                           192
# BZINESS LITE BOV                        176
# Name: Model, dtype: int64

# %%
df
# Out:
#       S.No                        Company  \
# 0        1      Maruti Suzuki India Ltd.,
# 1        2      Maruti Suzuki India Ltd.,
# 2        3      Maruti Suzuki India Ltd.,
# 3        4          Tvs Motor Company Ltd
# 4        5          Tvs Motor Company Ltd
# ...    ...                            ...
# 8686  8695             Pur Energy Pvt Ltd
# 8687  8696  M/S Goreen E-Mobility Pvt Ltd
# 8688  8697  M/S Goreen E-Mobility Pvt Ltd
# 8689  8698           Klb Komaki Pvt. Ltd.
# 8690  8699           Klb Komaki Pvt. Ltd.
#
#                                                   Model             Fuel  \
# 0     MARUTI - CIAZ SMART HYBRID SIGMA 1.5L 5MT BSVI...  Petrol Electric
# 1     MARUTI - CIAZ SMART HYBRID SIGMA 1.5L 5MT BSVI...  Petrol Electric
# 2     MARUTI - CIAZ SMART HYBRID SIGMA 1.5L 5MT BSVI...  Petrol Electric
# 3                              TVS IQUBE ELECTRIC S BOV          Battery
# 4                   TVS IQUBE ELECTRIC SMARTXONNECT BOV          Battery
# ...

# %%
sns.countplot(x = 'Fuel' , data =df)
# Out:
# <AxesSubplot:xlabel='Fuel', ylabel='count'>

# %%
f, ax = plt.subplots(figsize=(9, 6))
sns.countplot(x = 'Vehicle Class' , data =df)
ax.tick_params(axis='x', rotation=90)

# %%
sns.countplot(x = 'Insurance Validity (in years)' , data =df)
# Out:
# <AxesSubplot:xlabel='Insurance Validity (in years)', ylabel='count'>

# %%
sns.countplot(x = 'Vehicle age (in months)' , data =df)
# Out:
# <AxesSubplot:xlabel='Vehicle age (in months)', ylabel='count'>

# %%
sns.countplot(x = 'Seats' , data =df)
# Out:
# <AxesSubplot:xlabel='Seats', ylabel='count'>

# %%
sns.countplot(x = 'Second Vehicle' , data =df)
# Out:
# <AxesSubplot:xlabel='Second Vehicle', ylabel='count'>

# %%
sns.countplot(x = 'Category' , data =df)
# Out:
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %%
f, ax = plt.subplots(figsize=(9, 6))
sns.countplot(x = 'Body Type' , data =df)
ax.tick_params(axis='x', rotation=90)

# %%
sns.countplot(x = 'CC' , data =df)
# Out:
# <AxesSubplot:xlabel='CC', ylabel='count'>
